# %% [markdown]
# # **SUMMER ANALYTICS 2024**

# %% [markdown]
# # Week - 1 Assignment

# %% [markdown]
# # **Data Grand Prix!**

# %% [markdown]
# **Welcome to your first assignment of Summer Analytics 2025! We hope you are excited to implement and test everything you have learnt up until now. The dataset which you'll use includes information about cars.**
#
# **We've got an interesting set of questions for you to get a basic understanding of pandas and data visualization libraries. GOOD LUCK!**
#
#
# ***Let's get started with importing numpy, pandas, seaborn and matplotlib!***
#
# Note - matplotlib should be imported with the command :
#
#  `import matplotlib.pyplot as plt`

# %% [markdown]
# ### 1) Start by importing all important libraries
# For eg, "import numpy as np"

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ### 2) Read the csv file and assign it to a variable .

# %%
cars_data = pd.read_csv("/content/Cars.csv")

# %%
cars_data
# Out:
#       mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 0    18.0          8         307.0       130.0    3504          12.0
# 1    15.0          8         350.0       165.0    3693          11.5
# 2    18.0          8         318.0       150.0    3436          11.0
# 3    16.0          8         304.0       150.0    3433          12.0
# 4    17.0          8         302.0       140.0    3449          10.5
# ..    ...        ...           ...         ...     ...           ...
# 393  27.0          4         140.0        86.0    2790          15.6
# 394  44.0          4          97.0        52.0    2130          24.6
# 395  32.0          4         135.0        84.0    2295          11.6
# 396  28.0          4         120.0        79.0    2625          18.6
# 397  31.0          4         119.0        82.0    2720          19.4
#
#      model_year  origin                       name
# 0            70     usa  chevrolet chevelle malibu
# 1            70     usa          buick skylark 320
# 2            70     usa         plymouth satellite
# 3            70     usa              amc rebel sst
# 4            70     usa                ford torino
# ..          ...     ...                        ...
# 393          82     usa            ford mustang gl
# 394          82  europe                  vw pickup
# 395          82     usa              dodge rampage
# 396          82     usa                ford ranger
# 397          82     usa                 chevy s-10
#
# [398 rows x 9 columns]

# %% [markdown]
# ### 3) Display shape of dataframe
# Expected Output - (398, 9)

# %%
cars_data.shape
# Out:
# (398, 9)

# %% [markdown]
# ### 4) Print all columns of dataframe
# Return an array containing names of all the columns.

# %%
cols = list(cars_data.columns)
cols
# Out:
# ['mpg',
#  'cylinders',
#  'displacement',
#  'horsepower',
#  'weight',
#  'acceleration',
#  'model_year',
#  'origin',
#  'name']

# %% [markdown]
# ### 6) Set the 'name' column as the index of dataframe

# %%
cars_data.set_index('name', inplace=True)
# if it's not required to make a permanent change to the actual dataframe, then inplace = True can be removed

# %%
cars_data
# Out:
#                             mpg  cylinders  displacement  horsepower  weight  \
# name
# chevrolet chevelle malibu  18.0          8         307.0       130.0    3504
# buick skylark 320          15.0          8         350.0       165.0    3693
# plymouth satellite         18.0          8         318.0       150.0    3436
# amc rebel sst              16.0          8         304.0       150.0    3433
# ford torino                17.0          8         302.0       140.0    3449
# ...                         ...        ...           ...         ...     ...
# ford mustang gl            27.0          4         140.0        86.0    2790
# vw pickup                  44.0          4          97.0        52.0    2130
# dodge rampage              32.0          4         135.0        84.0    2295
# ford ranger                28.0          4         120.0        79.0    2625
# chevy s-10                 31.0          4         119.0        82.0    2720
#
#                            acceleration  model_year  origin
# name
# chevrolet chevelle malibu          12.0          70     usa
# buick skylark 320                  11.5          70     usa
# plymouth satellite                 11.0          70     usa
# amc rebel sst                      12.0          70     usa
# ford torino                        10.5          70     usa
# ...                                 ...         ...     ...
# ford mustang gl                    15.6          82     usa
# vw pickup                          24.6          82  europe
# dodge rampage                      11.6          82     usa
# ford ranger                        18.6          82     usa
# chevy s-10                         19.4          82     usa
#
# [398 rows x 8 columns]

# %% [markdown]
# ###  7) Print a list of all the unique mpg values

# %%
cars_data['mpg'].unique()
# Out:
# array([18. , 15. , 16. , 17. , 14. , 24. , 22. , 21. , 27. , 26. , 25. ,
#        10. , 11. ,  9. , 28. , 19. , 12. , 13. , 23. , 30. , 31. , 35. ,
#        20. , 29. , 32. , 33. , 17.5, 15.5, 14.5, 22.5, 24.5, 18.5, 29.5,
#        26.5, 16.5, 31.5, 36. , 25.5, 33.5, 20.5, 30.5, 21.5, 43.1, 36.1,
#        32.8, 39.4, 19.9, 19.4, 20.2, 19.2, 25.1, 20.6, 20.8, 18.6, 18.1,
#        17.7, 27.5, 27.2, 30.9, 21.1, 23.2, 23.8, 23.9, 20.3, 21.6, 16.2,
#        19.8, 22.3, 17.6, 18.2, 16.9, 31.9, 34.1, 35.7, 27.4, 25.4, 34.2,
#        34.5, 31.8, 37.3, 28.4, 28.8, 26.8, 41.5, 38.1, 32.1, 37.2, 26.4,
#        24.3, 19.1, 34.3, 29.8, 31.3, 37. , 32.2, 46.6, 27.9, 40.8, 44.3,
#        43.4, 36.4, 44.6, 40.9, 33.8, 32.7, 23.7, 23.6, 32.4, 26.6, 25.8,
#        23.5, 39.1, 39. , 35.1, 32.3, 37.7, 34.7, 34.4, 29.9, 33.7, 32.9,
#        31.6, 28.1, 30.7, 24.2, 22.4, 34. , 38. , 44. ])

# %% [markdown]
# ### 8) Create a column which contains the horsepower divided by weight as its metric and make this new column the index.

# %%
cars_data['Power_to_Weight_Ratio'] = cars_data['horsepower'] / cars_data['weight']
cars_data
# Out:
#                             mpg  cylinders  displacement  horsepower  weight  \
# name
# chevrolet chevelle malibu  18.0          8         307.0       130.0    3504
# buick skylark 320          15.0          8         350.0       165.0    3693
# plymouth satellite         18.0          8         318.0       150.0    3436
# amc rebel sst              16.0          8         304.0       150.0    3433
# ford torino                17.0          8         302.0       140.0    3449
# ...                         ...        ...           ...         ...     ...
# ford mustang gl            27.0          4         140.0        86.0    2790
# vw pickup                  44.0          4          97.0        52.0    2130
# dodge rampage              32.0          4         135.0        84.0    2295
# ford ranger                28.0          4         120.0        79.0    2625
# chevy s-10                 31.0          4         119.0        82.0    2720
#
#                            acceleration  model_year  origin  \
# name
# chevrolet chevelle malibu          12.0          70     usa
# buick skylark 320                  11.5          70     usa
# plymouth satellite                 11.0          70     usa
# amc rebel sst                      12.0          70     usa
# ford torino                        10.5          70     usa
# ...                                 ...         ...     ...
# ford mustang gl                    15.6          82     usa
# vw pickup                          24.6          82  europe
# dodge rampage                      11.6          82     usa
# ford ranger                        18.6          82     usa
# chevy s-10                         19.4          82     usa
#
#                            Power_to_Weight_Ratio
# name
# chevrolet chevelle malibu               0.037100
# buick skylark 320                       0.044679
# plymouth satellite                      0.043655
# amc rebel sst                           0.043694
# ford torino                             0.040591
# ...                                          ...
# ford mustang gl                         0.030824
# vw pickup                               0.024413
# dodge rampage                           0.036601
# ford ranger                             0.030095
# chevy s-10                              0.030147
#
# [398 rows x 9 columns]

# %%
cars_data.reset_index(inplace=True)
cars_data
# Out:
#                           name   mpg  cylinders  displacement  horsepower  \
# 0    chevrolet chevelle malibu  18.0          8         307.0       130.0
# 1            buick skylark 320  15.0          8         350.0       165.0
# 2           plymouth satellite  18.0          8         318.0       150.0
# 3                amc rebel sst  16.0          8         304.0       150.0
# 4                  ford torino  17.0          8         302.0       140.0
# ..                         ...   ...        ...           ...         ...
# 393            ford mustang gl  27.0          4         140.0        86.0
# 394                  vw pickup  44.0          4          97.0        52.0
# 395              dodge rampage  32.0          4         135.0        84.0
# 396                ford ranger  28.0          4         120.0        79.0
# 397                 chevy s-10  31.0          4         119.0        82.0
#
#      weight  acceleration  model_year  origin  Power_to_Weight_Ratio
# 0      3504          12.0          70     usa               0.037100
# 1      3693          11.5          70     usa               0.044679
# 2      3436          11.0          70     usa               0.043655
# 3      3433          12.0          70     usa               0.043694
# 4      3449          10.5          70     usa               0.040591
# ..      ...           ...         ...     ...                    ...
# 393    2790          15.6          82     usa               0.030824
# 394    2130          24.6          82  europe               0.024413
# 395    2295          11.6          82     usa               0.036601
# 396    2625          18.6          82     usa               0.030095
# 397    2720          19.4          82     usa               0.030147
#
# [398 rows x 10 columns]

# %%
cars_data.set_index('Power_to_Weight_Ratio', inplace=True)
cars_data
# Out:
#                                             name   mpg  cylinders  \
# Power_to_Weight_Ratio
# 0.037100               chevrolet chevelle malibu  18.0          8
# 0.044679                       buick skylark 320  15.0          8
# 0.043655                      plymouth satellite  18.0          8
# 0.043694                           amc rebel sst  16.0          8
# 0.040591                             ford torino  17.0          8
# ...                                          ...   ...        ...
# 0.030824                         ford mustang gl  27.0          4
# 0.024413                               vw pickup  44.0          4
# 0.036601                           dodge rampage  32.0          4
# 0.030095                             ford ranger  28.0          4
# 0.030147                              chevy s-10  31.0          4
#
#                        displacement  horsepower  weight  acceleration  \
# Power_to_Weight_Ratio
# 0.037100                      307.0       130.0    3504          12.0
# 0.044679                      350.0       165.0    3693          11.5
# 0.043655                      318.0       150.0    3436          11.0
# 0.043694                      304.0       150.0    3433          12.0
# 0.040591                      302.0       140.0    3449          10.5
# ...                             ...         ...     ...           ...
# 0.030824                      140.0        86.0    2790          15.6
# 0.024413                       97.0        52.0    2130          24.6
# 0.036601                      135.0        84.0    2295          11.6
# 0.030095                      120.0        79.0    2625          18.6
# 0.030147                      119.0        82.0    2720          19.4
#
#                        model_year  origin
# Power_to_Weight_Ratio
# 0.037100                       70     usa
# 0.044679                       70     usa
# 0.043655                       70     usa
# 0.043694                       70     usa
# 0.040591                       70     usa
# ...                           ...     ...
# 0.030824                       82     usa
# 0.024413                       82  europe
# 0.036601                       82     usa
# 0.030095                       82     usa
# 0.030147                       82     usa
#
# [398 rows x 9 columns]

# %% [markdown]
# ![OIP (1).jpg](data:image/jpeg;base64,...)

# %% [markdown]
#  **Checkpoint!!
# Congratulations on making it this far. You are really keeping up in Data Grand Prix.
# Now starts the real race i.e. graded questions of the quiz.**

# %%
cars_data
# Out:
#                                             name   mpg  cylinders  \
# Power_to_Weight_Ratio
# 0.037100               chevrolet chevelle malibu  18.0          8
# 0.044679                       buick skylark 320  15.0          8
# 0.043655                      plymouth satellite  18.0          8
# 0.043694                           amc rebel sst  16.0          8
# 0.040591                             ford torino  17.0          8
# ...                                          ...   ...        ...
# 0.030824                         ford mustang gl  27.0          4
# 0.024413                               vw pickup  44.0          4
# 0.036601                           dodge rampage  32.0          4
# 0.030095                             ford ranger  28.0          4
# 0.030147                              chevy s-10  31.0          4
#
#                        displacement  horsepower  weight  acceleration  \
# Power_to_Weight_Ratio
# 0.037100                      307.0       130.0    3504          12.0
# 0.044679                      350.0       165.0    3693          11.5
# 0.043655                      318.0       150.0    3436          11.0
# 0.043694                      304.0       150.0    3433          12.0
# 0.040591                      302.0       140.0    3449          10.5
# ...                             ...         ...     ...           ...
# 0.030824                      140.0        86.0    2790          15.6
# 0.024413                       97.0        52.0    2130          24.6
# 0.036601                      135.0        84.0    2295          11.6
# 0.030095                      120.0        79.0    2625          18.6
# 0.030147                      119.0        82.0    2720          19.4
#
#                        model_year  origin
# Power_to_Weight_Ratio
# 0.037100                       70     usa
# 0.044679                       70     usa
# 0.043655                       70     usa
# 0.043694                       70     usa
# 0.040591                       70     usa
# ...                           ...     ...
# 0.030824                       82     usa
# 0.024413                       82  europe
# 0.036601                       82     usa
# 0.030095                       82     usa
# 0.030147                       82     usa
#
# [398 rows x 9 columns]

# %% [markdown]
# ## GRADED Questions (To be answered in the quiz)
# ### Try to retrieve some information from the data and answer the questions below . BEST OF LUCK !!

# %% [markdown]
# ### 1. What is name of car that has the highest horsepower?

# %%
cars_data['name'].loc[cars_data['horsepower'].idxmax()]
# Out:
# 'pontiac grand prix'

# %% [markdown]
# Verifying the result by a bit of manual data analysis

# %%
cars_data[cars_data['name'] == 'pontiac grand prix']
# Out:
#                                      name   mpg  cylinders  displacement  \
# Power_to_Weight_Ratio
# 0.053763               pontiac grand prix  16.0          8         400.0
#
#                        horsepower  weight  acceleration  model_year origin
# Power_to_Weight_Ratio
# 0.053763                    230.0    4278           9.5          73    usa

# %%
cars_data['horsepower'].describe()
# Out:
# count    392.000000
# mean     104.469388
# std       38.491160
# min       46.000000
# 25%       75.000000
# 50%       93.500000
# 75%      126.000000
# max      230.000000
# Name: horsepower, dtype: float64

# %% [markdown]
# The max horsepower provided in the data column description matches the value provided in the data row. Therefore the answer is correct.

# %% [markdown]
# ### 2. How many cars have mpg ≥ 35?

# %%
cars_data[cars_data['mpg'] >= 35].shape[0]
# Out:
# 36

# %% [markdown]
# ### 3. What is the most common origin for cars with horsepower > 100 and weight < 3000?

# %%
cars_data['origin'][(cars_data['horsepower'] > 100) & (cars_data['weight'] < 3000)].mode()[0]
# Out:
# 'usa'

# %% [markdown]
# ### 4. What is the mean acceleration of cars from Japan? (rounded to 2 decimals)

# %%
mean_acc_japan = cars_data['acceleration'][cars_data['origin'] == 'japan'].mean()
print("{:.2f}".format(mean_acc_japan))
# Out:
# 16.17

# %% [markdown]
# ### 5. Which year had the highest average mpg?

# %%
int(cars_data.groupby('model_year')['mpg'].mean().idxmax())
# Out:
# 80

# %% [markdown]
# ## *Congratulations on coming this far! Since we were having so much fun playing with this dataset, let's move towards finish line by attempting some Ungraded questions!*
#
# ### **Note:** These questions are UNGRADED, and are given as an extra exercise.

# %% [markdown]
# ### Find the car (or cars) with the best ratio of horsepower to weight among all cars that also have above-median mpg.

# %%
mean_mpg = cars_data['mpg'].mean()
float(mean_mpg)
# Out:
# 23.514572864321607

# %%
max_ratio = cars_data.index.max()
max_ratio
# Out:
# 0.0729099157485418

# %%
cars_data['name'][(cars_data.index == max_ratio) & (cars_data['mpg'] > mean_mpg)]
# Out:
# Series([], Name: name, dtype: object)

# %% [markdown]
# No cars exist that have above average MPG as well as the maximum possible power_to_weight ratio, so I will print the top 5 power_to_ratio cars that have an MPG above the average value.

# %%
cars_data[cars_data['mpg'] > mean_mpg].sort_index(ascending=False).head(3)
# Out:
#                                      name   mpg  cylinders  displacement  \
# Power_to_Weight_Ratio
# 0.050582                         bmw 2002  26.0          4         121.0
# 0.045361                    datsun 280-zx  32.7          6         168.0
# 0.044316               chevrolet citation  28.8          6         173.0
#
#                        horsepower  weight  acceleration  model_year  origin
# Power_to_Weight_Ratio
# 0.050582                    113.0    2234          12.5          70  europe
# 0.045361                    132.0    2910          11.4          80   japan
# 0.044316                    115.0    2595          11.3          79     usa

# %% [markdown]
# The car with the highest power_to_weight ratio as well as an above-average MPG is **'BMW'**.

# %% [markdown]
# ### Design a multi-line plot using Matplotlib or Seaborn that shows the evolution of average mpg over the years, separately for each origin

# %%
avg_mpg_by_year_origin = cars_data.groupby(['model_year', 'origin'])['mpg'].mean().reset_index()

plt.figure(figsize=(5, 4))
sns.lineplot(data=avg_mpg_by_year_origin, x='model_year', y='mpg', hue='origin', marker='o')

plt.title('Evolution of Average MPG Over the Years by Origin')
plt.xlabel('Model Year')
plt.ylabel('Average MPG')
plt.legend(title='Origin')
plt.grid(True)
plt.tight_layout()
plt.show()

# %% [markdown]
# ### Create a Seaborn scatterplot (or PairGrid) where:
#
# X = horsepower
#
# Y = weight
#
# Color by: origin
#
# Size by: mpg
#
# Hue order = ['japan', 'europe', 'usa']
#
# Add meaningful plot titles and axis titles.

# %%
cars_clean = cars_data.dropna(subset=['horsepower', 'weight', 'origin', 'mpg'])
hue_order = ['japan', 'europe', 'usa']

plt.figure(figsize=(8, 6))
scatter = sns.scatterplot(
    data=cars_clean,
    x='horsepower', y='weight',
    hue='origin', size='mpg',
    hue_order=hue_order,
    sizes=(20, 200),
    palette='Set2', alpha=0.7, edgecolor='gray'
)

plt.title('Horsepower VS Weight', fontsize=16)
plt.xlabel('Horsepower', fontsize=12)
plt.ylabel('Weight', fontsize=12)
plt.legend(title='Origin', bbox_to_anchor=(1.05, 1), loc='upper left')
plt.tight_layout()
plt.show()

# %% [markdown]
# ### We define a “consistent” car model as one that was produced over multiple years and had very low variation in mpg across those years (standard deviation < 1.0).
#
# Tasks:
#
# Identify car names that appear in more than one model_year.
#
# For each such name, compute the standard deviation of mpg across years.
#
# Return the car(s) with the lowest variation in mpg, among those with at least 2 appearances and std(mpg) < 1.0.
#
# Report the model name(s), number of appearances, and the average mpg.
#
# Bonus:
# Sort the result by number of appearances (descending), then mpg (descending).

# %%
multi_year_cars = cars_data.groupby('name')['model_year'].nunique().reset_index()
multi_year_cars = multi_year_cars[multi_year_cars['model_year'] > 1]
multi_year_cars.head()
# Out:
#                 name  model_year
# 3        amc concord           2
# 7        amc gremlin           4
# 8         amc hornet           4
# 10       amc matador           5
# 11  amc matador (sw)           2

# %%
cars_multi_year = cars_data[cars_data['name'].isin(multi_year_cars['name'])]

mpg_stats = cars_multi_year.groupby('name').agg(
    count=('mpg', 'count'),
    std_mpg=('mpg', 'std'),
    avg_mpg=('mpg', 'mean')
).reset_index()

mpg_stats.head()
# Out:
#                name  count   std_mpg  avg_mpg
# 0       amc concord      2  3.464823   21.850
# 1       amc gremlin      4  1.290994   19.500
# 2        amc hornet      4  2.136001   19.375
# 3       amc matador      5  1.483240   15.700
# 4  amc matador (sw)      2  0.707107   14.500

# %%
consistent_cars = mpg_stats[(mpg_stats['std_mpg'] < 1.0) & (mpg_stats['count'] >= 2)]
consistent_cars.head()
# Out:
#                          name  count   std_mpg    avg_mpg
# 4            amc matador (sw)      2  0.707107  14.500000
# 10  chevrolet chevelle malibu      2  0.707107  17.500000
# 21               datsun pl510      2  0.000000  27.000000
# 22                dodge aspen      2  0.353553  18.850000
# 26           ford galaxie 500      3  0.577350  14.333333

# %%
min_std = consistent_cars['std_mpg'].min()
most_consistent = consistent_cars[consistent_cars['std_mpg'] == min_std]
most_consistent
# Out:
#             name  count  std_mpg  avg_mpg
# 21  datsun pl510      2      0.0     27.0

# %%
sorted_consistent = consistent_cars.sort_values(by=['count', 'avg_mpg'], ascending=[False, False])
sorted_consistent
# Out:
#                          name  count   std_mpg    avg_mpg
# 26           ford galaxie 500      3  0.577350  14.333333
# 41          plymouth fury iii      3  0.577350  14.333333
# 49        toyota corolla 1200      2  0.707107  31.500000
# 35                  mazda 626      2  0.212132  31.450000
# 53          volkswagen rabbit      2  0.353553  29.250000
# 21               datsun pl510      2  0.000000  27.000000
# 45                  saab 99le      2  0.707107  24.500000
# 51             toyota mark ii      2  0.707107  19.500000
# 22                dodge aspen      2  0.353553  18.850000
# 10  chevrolet chevelle malibu      2  0.707107  17.500000
# 4            amc matador (sw)      2  0.707107  14.500000
# 28      ford gran torino (sw)      2  0.707107  13.500000
# 29                   ford ltd      2  0.707107  13.500000

# %% [markdown]
# **Congratulations on completing the race. Kudos to you. Looking forward to meet you in next week.**
